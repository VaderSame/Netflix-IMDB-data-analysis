# %%
# %cd /content/drive/MyDrive/Colab Notebooks/Netflix-Movies-and-TVshows-Visualization-PowerBI-master
# Out:
# /content/drive/MyDrive/Colab Notebooks/Netflix-Movies-and-TVshows-Visualization-PowerBI-master

# %%
# !ls
# Out:
# background  data_preparation.ipynb  Netflix-Movies-and-TVshows-Visualization-PowerBI-dashboard.pbix
# data	    img			    README.md

# %%
import pandas as pd
import numpy as np

# %%
title_ratings = pd.read_csv("data/title.ratings.tsv/data.tsv", sep='\t')
# title_ratings = pd.read_csv("data/title.ratings.csv")
title_ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      2007
# 1  tt0000002            5.8       270
# 2  tt0000003            6.5      1920
# 3  tt0000004            5.5       178
# 4  tt0000005            6.2      2697

# %%
title_basics = pd.read_csv("data/title.basics.tsv/data.tsv", sep='\t')
# title_basics = pd.read_csv("title.basics.csv")
title_basics.head()
# Out:
# <ipython-input-10-32be72b3a551>:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   title_basics = pd.read_csv("data/title.basics.tsv/data.tsv", sep='\t')
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
title_basics = title_basics[['titleType','tconst','primaryTitle', 'originalTitle', 'startYear']]
# title_basics = title_basics[title_basics.titleType=='movie']
title_basics = title_basics[title_basics.startYear.apply(lambda x: str(x).isnumeric())]
title_basics.head()
# Out:
#   titleType     tconst            primaryTitle           originalTitle  \
# 0     short  tt0000001              Carmencita              Carmencita
# 1     short  tt0000002  Le clown et ses chiens  Le clown et ses chiens
# 2     short  tt0000003          Pauvre Pierrot          Pauvre Pierrot
# 3     short  tt0000004             Un bon bock             Un bon bock
# 4     short  tt0000005        Blacksmith Scene        Blacksmith Scene
#
#   startYear
# 0      1894
# 1      1892
# 2      1892
# 3      1892
# 4      1893

# %%
print(title_ratings.shape)
print(title_basics.shape)
# Out:
# (1376742, 3)
# (8988139, 5)

# %%
ratings_and_titles = pd.merge(title_ratings.set_index('tconst'), title_basics.set_index('tconst'), left_index=True, right_index=True, how='inner')
ratings_and_titles = ratings_and_titles.drop_duplicates()
ratings_and_titles
# Out:
#            averageRating  numVotes  titleType                primaryTitle  \
# tconst
# tt0000001            5.7      2007      short                  Carmencita
# tt0000002            5.8       270      short      Le clown et ses chiens
# tt0000003            6.5      1920      short              Pauvre Pierrot
# tt0000004            5.5       178      short                 Un bon bock
# tt0000005            6.2      2697      short            Blacksmith Scene
# ...                  ...       ...        ...                         ...
# tt9916730            7.6        11      movie                      6 Gunn
# tt9916766            7.0        22  tvEpisode              Episode #10.15
# tt9916778            7.2        36  tvEpisode                      Escape
# tt9916840            8.8         6  tvEpisode  Horrid Henry's Comic Caper
# tt9916880            8.2         6  tvEpisode   Horrid Henry Knows It All
#
#                         originalTitle startYear
# tconst
# tt0000001                  Carmencita      1894
# tt0000002      Le clown et ses chiens      1892
# tt0000003              Pauvre Pierrot      1892
# tt0000004                 Un bon bock      1892
# tt0000005            Blacksmith Scene      1893
# ...                               ...       ...
# tt9916730                      6 Gunn      2017
# tt9916766              Episode #10.15      2019
# tt9916778                      Escape      2019
# tt9916840  Horrid Henry's Comic Caper      2014
# tt9916880   Horrid Henry Knows It All      2014
#
# [1374066 rows x 6 columns]

# %%
netflix_titles = pd.read_csv("data/netflix_titles.csv")
print(netflix_titles.shape)
netflix_titles = netflix_titles.dropna(subset=['release_year'])
netflix_titles.release_year = netflix_titles.release_year.astype(np.int64)
print(netflix_titles.shape)
netflix_titles.head()
# Out:
# (8807, 12)
# (8807, 12)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
ratings_and_titles = ratings_and_titles[ratings_and_titles.startYear.apply(lambda x: str(x).isnumeric())]
ratings_and_titles.startYear = ratings_and_titles.startYear.astype(np.int64)
ratings_and_titles.head()
# Out:
#            averageRating  numVotes titleType            primaryTitle  \
# tconst
# tt0000001            5.7      2007     short              Carmencita
# tt0000002            5.8       270     short  Le clown et ses chiens
# tt0000003            6.5      1920     short          Pauvre Pierrot
# tt0000004            5.5       178     short             Un bon bock
# tt0000005            6.2      2697     short        Blacksmith Scene
#
#                     originalTitle  startYear
# tconst
# tt0000001              Carmencita       1894
# tt0000002  Le clown et ses chiens       1892
# tt0000003          Pauvre Pierrot       1892
# tt0000004             Un bon bock       1892
# tt0000005        Blacksmith Scene       1893

# %%
netflix_titles['title_low'] = netflix_titles['title'].str.lower()
ratings_and_titles['originalTitle_low'] = ratings_and_titles['originalTitle'].str.lower()
ratings_and_titles['primaryTitle_low'] = ratings_and_titles['primaryTitle'].str.lower()
ratings_and_titles.head()
# Out:
#            averageRating  numVotes titleType            primaryTitle  \
# tconst
# tt0000001            5.7      2007     short              Carmencita
# tt0000002            5.8       270     short  Le clown et ses chiens
# tt0000003            6.5      1920     short          Pauvre Pierrot
# tt0000004            5.5       178     short             Un bon bock
# tt0000005            6.2      2697     short        Blacksmith Scene
#
#                     originalTitle  startYear       originalTitle_low  \
# tconst
# tt0000001              Carmencita       1894              carmencita
# tt0000002  Le clown et ses chiens       1892  le clown et ses chiens
# tt0000003          Pauvre Pierrot       1892          pauvre pierrot
# tt0000004             Un bon bock       1892             un bon bock
# tt0000005        Blacksmith Scene       1893        blacksmith scene
#
#                  primaryTitle_low
# tconst
# tt0000001              carmencita
# tt0000002  le clown et ses chiens
# tt0000003          pauvre pierrot
# tt0000004             un bon bock
# tt0000005        blacksmith scene

# %%
ratings_and_titles[ratings_and_titles['primaryTitle']=='Breaking Bad']
# Out:
#             averageRating  numVotes  titleType  primaryTitle originalTitle  \
# tconst
# tt0903747             9.5   2068760   tvSeries  Breaking Bad  Breaking Bad
# tt10975068            7.7        28  tvEpisode  Breaking Bad  Breaking Bad
# tt12188568            9.0     25720  tvEpisode  Breaking Bad  Breaking Bad
# tt1718535             7.2        26  tvEpisode  Breaking Bad  Breaking Bad
# tt2329627             6.4        30  tvEpisode  Breaking Bad  Breaking Bad
# tt2931468             5.2        11  tvEpisode  Breaking Bad  Breaking Bad
# tt3075216             7.9        83  tvEpisode  Breaking Bad  Breaking Bad
# tt3105216             8.0       151  tvEpisode  Breaking Bad  Breaking Bad
# tt3129166             6.7        25  tvEpisode  Breaking Bad  Breaking Bad
# tt3699148             4.3         8  tvEpisode  Breaking Bad  Breaking Bad
# tt3864062             6.3        13  tvEpisode  Breaking Bad  Breaking Bad
# tt4111020             5.9         9  tvEpisode  Breaking Bad  Breaking Bad
# tt6949164             4.9        19  tvEpisode  Breaking Bad  Breaking Bad
# tt7017416             7.5       200  tvEpisode  Breaking Bad  Breaking Bad
# tt7557776             8.3        28  tvEpisode  Breaking Bad  Breaking Bad
# tt9046084             8.9       266  tvEpisode  Breaking Bad  Breaking Bad
#
#             startYear originalTitle_low primaryTitle_low
# tconst
# tt0903747        2008      breaking bad     breaking bad
# tt10975068       2019      breaking bad     breaking bad
# tt12188568       2022      breaking bad     breaking bad
# tt1718535        2011      breaking bad     breaking bad
# tt2329627        2012      breaking bad     breaking bad
# tt2931468        2012      breaking bad     breaking bad
# tt3075216        2013      breaking bad     breaking bad
# tt3105216        2013      breaking bad     breaking bad
# tt3129166        2013      breaking bad     breaking bad
# tt3699148        2013      breaking bad     breaking bad
# tt3864062        2014      breaking bad     breaking bad
# tt4111020        2013      breaking bad     breaking bad
# tt6949164        2017      breaking bad     breaking bad
# tt7017416        2018      breaking bad     breaking bad
# tt7557776        2017      breaking bad     breaking bad
# tt9046084        2018      breaking bad     breaking bad

# %%
ratings_and_titles['all_averageRating'] = ratings_and_titles['averageRating'] * ratings_and_titles['numVotes']
ratings_and_titles.head()
# Out:
#            averageRating  numVotes titleType            primaryTitle  \
# tconst
# tt0000001            5.7      2007     short              Carmencita
# tt0000002            5.8       270     short  Le clown et ses chiens
# tt0000003            6.5      1920     short          Pauvre Pierrot
# tt0000004            5.5       178     short             Un bon bock
# tt0000005            6.2      2697     short        Blacksmith Scene
#
#                     originalTitle  startYear       originalTitle_low  \
# tconst
# tt0000001              Carmencita       1894              carmencita
# tt0000002  Le clown et ses chiens       1892  le clown et ses chiens
# tt0000003          Pauvre Pierrot       1892          pauvre pierrot
# tt0000004             Un bon bock       1892             un bon bock
# tt0000005        Blacksmith Scene       1893        blacksmith scene
#
#                  primaryTitle_low  all_averageRating
# tconst
# tt0000001              carmencita            11439.9
# tt0000002  le clown et ses chiens             1566.0
# tt0000003          pauvre pierrot            12480.0
# tt0000004             un bon bock              979.0
# tt0000005        blacksmith scene            16721.4

# %%
grouped_ratings_and_titles = ratings_and_titles.groupby(by=['primaryTitle_low'])[['numVotes', 'all_averageRating']].sum().reset_index()
grouped_ratings_and_titles['averageRating'] = grouped_ratings_and_titles[['all_averageRating']].div(grouped_ratings_and_titles.numVotes, axis=0)
grouped_ratings_and_titles['averageRating'] = grouped_ratings_and_titles['averageRating'].round(1)

grouped_ratings_and_titles
# Out:
#               primaryTitle_low  numVotes  all_averageRating  averageRating
# 0                       !next?        20              102.0            5.1
# 1            !que ve el bisbe!        12               74.4            6.2
# 2        !women art revolution       256             1740.8            6.8
# 3                            #        32              178.4            5.6
# 4                     # my ass         9               61.2            6.8
# ...                        ...       ...                ...            ...
# 1022559               þáttur 1         9               66.6            7.4
# 1022560               þáttur 2         9               68.4            7.6
# 1022561               þú og ég        13               80.6            6.2
# 1022562  špansko the continent        23              144.9            6.3
# 1022563           【oshi no ko】      7114            59757.6            8.4
#
# [1022564 rows x 4 columns]

# %%
final = pd.merge(netflix_titles, grouped_ratings_and_titles, left_on=['title_low'], right_on=['primaryTitle_low'], how='left')
final = final.drop(['title_low', 'primaryTitle_low', 'all_averageRating'], axis=1)
final = final.rename(columns={'averageRating':'IMDB_rating', 'numVotes':'IMDB_numvotes'})
print(final.shape)
final.head()
# Out:
# (8807, 14)
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description  IMDB_numvotes  \
# 0  As her father nears the end of his life, filmm...         7117.0
# 1  After crossing paths at a party, a Cape Town t...         4506.0
# 2  To protect his family from a powerful drug lor...         4310.0
# 3  Feuds, flirtations and toilet talk go down amo...          287.0
# 4  In a city of coaching centers known to train I...        78449.0
#
#    IMDB_rating
# 0          7.4
# 1          6.8
# 2          7.2
# 3          6.6
# 4          9.0

# %% [markdown]
# ## Cleaned Dataset

# %%
final.to_csv("data/netflix_titles_with_IMDB.csv", index=False)
